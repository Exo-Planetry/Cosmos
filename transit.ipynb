# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
df = pd.read_csv("TD_2023.11.22_08.37.40.csv")

# %%
df.head(15)
# Out:
#      pl_name  pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  pl_rade  \
# 0   55 Cnc e   2.808000   2.000000e-03  -2.000000e-03           0.0      NaN
# 1   55 Cnc e   0.736547   1.300000e-06  -1.400000e-06           0.0    1.875
# 2   55 Cnc e   0.736548   1.600000e-06  -1.200000e-06           0.0      NaN
# 3   55 Cnc e   0.736539   7.000000e-06  -7.000000e-06           0.0    1.910
# 4   55 Cnc e   2.796740   1.000000e-04  -1.000000e-04           0.0      NaN
# 5   55 Cnc e   0.736542   2.500000e-06  -2.800000e-06           0.0      NaN
# 6   55 Cnc e        NaN            NaN            NaN           NaN      NaN
# 7   55 Cnc e   0.736545   1.400000e-06  -1.500000e-06           0.0      NaN
# 8   55 Cnc e   0.736546   1.010000e-06  -1.010000e-06           0.0    1.915
# 9   55 Cnc e   0.736547   1.300000e-06  -1.300000e-06           0.0    1.947
# 10  55 Cnc e   0.736546   1.600000e-07  -1.600000e-07           0.0      NaN
# ...

# %%
print(df.size)
df.shape
# Out:
# 1536672
# (32014, 48)

# %%
df1 = df.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries, 16 to 32005
# Data columns (total 48 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          107 non-null    object
#  1   pl_orbper        107 non-null    float64
#  2   pl_orbpererr1    107 non-null    float64
#  3   pl_orbpererr2    107 non-null    float64
#  4   pl_orbperlim     107 non-null    float64
#  5   pl_rade          107 non-null    float64
#  6   pl_radeerr1      107 non-null    float64
#  7   pl_radeerr2      107 non-null    float64
#  8   pl_radelim       107 non-null    float64
#  9   pl_orbeccen      107 non-null    float64
#  10  pl_orbeccenerr1  107 non-null    float64
#  11  pl_orbeccenerr2  107 non-null    float64
#  12  pl_orbeccenlim   107 non-null    float64
#  13  pl_orbincl       107 non-null    float64
#  14  pl_orbinclerr1   107 non-null    float64
#  15  pl_orbinclerr2   107 non-null    float64
# ...

# %%
column_names = df1.columns
print(column_names)
# Out:
# Index(['pl_name', 'pl_orbper', 'pl_orbpererr1', 'pl_orbpererr2',
#        'pl_orbperlim', 'pl_rade', 'pl_radeerr1', 'pl_radeerr2', 'pl_radelim',
#        'pl_orbeccen', 'pl_orbeccenerr1', 'pl_orbeccenerr2', 'pl_orbeccenlim',
#        'pl_orbincl', 'pl_orbinclerr1', 'pl_orbinclerr2', 'pl_orbincllim',
#        'pl_tranmid', 'pl_tranmiderr1', 'pl_tranmiderr2', 'pl_tranmidlim',
#        'ttv_flag', 'pl_imppar', 'pl_impparerr1', 'pl_impparerr2',
#        'pl_impparlim', 'pl_trandep', 'pl_trandeperr1', 'pl_trandeperr2',
#        'pl_trandeplim', 'pl_trandur', 'pl_trandurerr1', 'pl_trandurerr2',
#        'pl_trandurlim', 'pl_ratdor', 'pl_ratdorerr1', 'pl_ratdorerr2',
#        'pl_ratdorlim', 'pl_ratror', 'pl_ratrorerr1', 'pl_ratrorerr2',
#        'pl_ratrorlim', 'sy_vmag', 'sy_vmagerr1', 'sy_vmagerr2', 'sy_kmag',
#        'sy_kmagerr1', 'sy_kmagerr2'],
#       dtype='object')

# %%
df1.head(15)
# Out:
#         pl_name  pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  \
# 16     55 Cnc e   0.736544   5.200000e-06  -5.200000e-06           0.0
# 43   CoRoT-10 b  13.240600   2.000000e-04  -2.000000e-04           0.0
# 63   CoRoT-16 b   5.352270   2.000000e-04  -2.000000e-04           0.0
# 154   CoRoT-9 b  95.273800   1.400000e-03  -1.400000e-03           0.0
# 439  HAT-P-14 b   4.627669   5.000000e-06  -5.000000e-06           0.0
# 453  HAT-P-16 b   2.775960   3.000000e-06  -3.000000e-06           0.0
# 534  HAT-P-24 b   3.355240   7.000000e-06  -7.000000e-06           0.0
# 551  HAT-P-26 b   4.234516   1.500000e-05  -1.500000e-05           0.0
# 568  HAT-P-29 b   5.723390   1.300000e-05  -1.300000e-05           0.0
# 597  HAT-P-31 b   5.005425   9.100000e-05  -9.200000e-05           0.0
# 609  HAT-P-32 b   2.150008   1.300000e-07  -1.300000e-07           0.0
# 636  HAT-P-35 b   3.646706   2.100000e-05  -2.100000e-05           0.0
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Select relevant features and target variable
features = df1[['pl_orbper', 'pl_rade', 'pl_orbeccen', 'pl_orbincl', 'pl_tranmid', 'pl_imppar', 'pl_trandep', 'pl_trandur', 'pl_ratdor', 'pl_ratror', 'sy_vmag', 'sy_kmag']]
target = df1['ttv_flag']

# %%
features.columns
# Out:
# Index(['pl_orbper', 'pl_rade', 'pl_orbeccen', 'pl_orbincl', 'pl_tranmid',
#        'pl_imppar', 'pl_trandep', 'pl_trandur', 'pl_ratdor', 'pl_ratror',
#        'sy_vmag', 'sy_kmag'],
#       dtype='object')

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train a RandomForestClassifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 1.00
# Precision: 0.00
# Recall: 0.00
# F1 Score: 0.00
# c:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1757: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Sample input data
sample_input = pd.DataFrame({
    'pl_orbper': [10.0],
    'pl_rade': [1.5],
    'pl_orbeccen': [0.1],
    'pl_orbincl': [89.0],
    'pl_tranmid': [2459000.0],
    'pl_imppar': [0.02],
    'pl_trandep': [0.01],
    'pl_trandur': [2.0],
    'pl_ratdor': [0.01],
    'pl_ratror': [0.1],
    'sy_vmag': [10.0],
    'sy_kmag': [8.0]
})

# Standardize the sample input
sample_input_scaled = scaler.transform(sample_input)

# Make predictions using the trained model
sample_output = model.predict(sample_input_scaled)

print("Sample Input:")
print(sample_input)
print("\nPredicted Output:")
print(sample_output)
# Out:
# Sample Input:
#    pl_orbper  pl_rade  pl_orbeccen  pl_orbincl  pl_tranmid  pl_imppar  \
# 0       10.0      1.5          0.1        89.0   2459000.0       0.02
#
#    pl_trandep  pl_trandur  pl_ratdor  pl_ratror  sy_vmag  sy_kmag
# 0        0.01         2.0       0.01        0.1     10.0      8.0
#
# Predicted Output:
# [0]

# %%
y_train.nunique()
# Out:
# 2

# %%
# Select only rows where ttv_flag is 1
class_1_data = df1[df1['ttv_flag'] == 1]

# Display the dataset for class 1
print("Dataset for Class 1:")
print(class_1_data)
# Out:
# Dataset for Class 1:
#            pl_name  pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim  \
# 2247      K2-266 d  14.697000   3.400000e-04  -3.500000e-04           0.0
# 2250      K2-266 e  19.482000   1.200000e-03  -1.200000e-03           0.0
# 4985   Kepler-11 b  10.303900   6.000000e-04  -1.000000e-03           0.0
# 5000   Kepler-11 c  13.024100   1.300000e-03  -8.000000e-04           0.0
# 5011   Kepler-11 d  22.684500   9.000000e-04  -9.000000e-04           0.0
# 5027   Kepler-11 e  31.999600   8.000000e-04  -1.200000e-03           0.0
# 5043   Kepler-11 f  46.688800   2.700000e-03  -3.200000e-03           0.0
# 31250    WASP-18 b   0.941452   2.400000e-07  -2.400000e-07           0.0
# 31256    WASP-18 b   0.941453   7.800000e-07  -8.600000e-07           0.0
#
#        pl_rade  pl_radeerr1  pl_radeerr2  pl_radelim  pl_orbeccen  ...  \
# 2247     2.930        0.140       -0.120         0.0      0.04700  ...
# ...

# %%
import joblib

# Save the trained model to a file
model_filename = 'random_forest_model.joblib'
joblib.dump(model, model_filename)

print(f"Model saved to {model_filename}")
# Out:
# Model saved to random_forest_model.joblib

# %%
# Select rows where ttv_flag is 0
class_0_data = df1[df1['ttv_flag'] == 0]

# Print message for class 0
print("Exoplanets with ttv_flag equal to 0 (not present):")
print(class_0_data[['pl_name', 'ttv_flag']])  # Displaying only 'pl_name' and 'ttv_flag' columns

# Select rows where ttv_flag is 1
class_1_data = df1[df1['ttv_flag'] == 1]

# Print message for class 1
print("\nExoplanets with ttv_flag equal to 1 (present):")
print(class_1_data[['pl_name', 'ttv_flag']])  # Displaying only 'pl_name' and 'ttv_flag' columns
# Out:
# Exoplanets with ttv_flag equal to 0 (not present):
#            pl_name  ttv_flag
# 16        55 Cnc e         0
# 43      CoRoT-10 b         0
# 63      CoRoT-16 b         0
# 154      CoRoT-9 b         0
# 439     HAT-P-14 b         0
# ...            ...       ...
# 31289    WASP-19 b         0
# 31793  WASP-77 A b         0
# 31814     WASP-8 b         0
# 31825    WASP-80 b         0
# 32005       XO-7 b         0
#
# [98 rows x 2 columns]
#
# Exoplanets with ttv_flag equal to 1 (present):
#            pl_name  ttv_flag
# 2247      K2-266 d         1
# 2250      K2-266 e         1
# 4985   Kepler-11 b         1
# 5000   Kepler-11 c         1
# 5011   Kepler-11 d         1
# 5027   Kepler-11 e         1
# 5043   Kepler-11 f         1
# 31250    WASP-18 b         1
# 31256    WASP-18 b         1

# %%
spectra = pd.read_csv('table.csv')

# %%
spectra.head(15)
# Out:
#          PL_NAME     SPEC_TYPE  MINWAVELNG  MAXWAVELNG    MINTRANMID  \
# 0   TRAPPIST-1 c      Emission      15.000      15.000           NaN
# 1      WASP-36 b      Emission       2.159       2.159           NaN
# 2      WASP-46 b      Emission       2.159       2.159           NaN
# 3       WASP-4 b      Emission       2.159       2.159           NaN
# 4       WASP-5 b      Emission       2.159       2.159           NaN
# 5      WASP-18 b      Emission       2.159       2.159           NaN
# 6      WASP-19 b      Emission       2.144       2.144           NaN
# 7      WASP-43 b      Emission       2.144       2.144           NaN
# 8      WASP-19 b  Transmission       0.866       0.866  2.456291e+06
# 9      WASP-19 b      Emission       0.866       0.866           NaN
# 10    HAT-P-32 b      Emission       3.600       4.500           NaN
# 11    HAT-P-32 b      Emission       1.635       2.150           NaN
# 12      WASP-3 b      Emission       2.150       2.150           NaN
# ...

# %%
df3 = spectra.dropna()

# %%
df3.head(15)
# Out:
#        PL_NAME     SPEC_TYPE  MINWAVELNG  MAXWAVELNG  MINTRANMID  MAXTRANMID  \
# 117  WASP-17 b  Transmission       0.385        0.56   2456086.5   2456086.5
# 118  WASP-17 b  Transmission       0.570        0.87   2456370.5   2456370.5
# 119  WASP-17 b  Transmission       0.385        0.56   2456366.5   2456366.5
#
#                                            NOTE
# 117  Reduced and Fitted Using Iraclis - visit 1
# 118  Reduced and Fitted Using Iraclis - visit 3
# 119  Reduced and Fitted Using Iraclis - visit 2
